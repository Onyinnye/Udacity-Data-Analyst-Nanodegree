# %% [markdown]
# ### Twitter users activity on WeRateDogs Portal
# - WeRateDogs is a Twitter account that rates people's dogs with a humorous comment about the dog. These ratings almost always have a denominator of 10. The numerators, though? Almost always greater than 10. 11/10, 12/10, 13/10, etc." WeRateDogs has over 7.89M followers (on March 2019) and has received international media coverage.
#
# #### Data Analysis & Visualization
#
# - After wrangling the Twitter data for the WeRateDogs website, I proceeded to analyse and visualize the dataset which contained 2060 tweets. I started by checking the breed that was majorly prdicted.

# %% [markdown]
# ![image.png](attachment:image.png),

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **From the bar chart above, the 3 majorly predicted breeds were the Labrador Retriever, the Golden Retriever and the Chihuahua dogs**

# %% [markdown]
# - I checked if favorites were likely to get more retweets

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **From the visualization, favourites were most likely to be retweeted by users**

# %% [markdown]
# I also checked how the page grew over the years, with respect to favorites and retweets

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - I discovered that:
# - Both retweet and favorite grew over the year although the favorite grew moree
# - there was a spike in favourite after october 2016
# - witth this analysis, it caan be seen that the we rate dog page has continually become popular and perharps would grow more over the years but would need to strategize to increase the number of retweets since retweets also help increase the popularity of page
